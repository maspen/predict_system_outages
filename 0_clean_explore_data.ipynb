# %%
import numpy as np
import pandas as pd
from collections import OrderedDict
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# data from the Ultrascale Systems Research Center (USRC) in Los Alamos
# 'This is failure/interrupt data for all systems from 1996 to 2005'

df = pd.read_csv('data/LA-UR-05-7318-failure-data-1996-2005_3.csv')
df.head(2)
# Out:
#    System machine type  nodes  procstot  procsinnode  nodenum  nodenumz  \
# 0       2      cluster   49.0    6152.0         80.0      0.0       0.0
# 1       2      cluster   49.0    6152.0         80.0      0.0       0.0
#
#   node install   node prod node decom  ... Prob Started (mm/dd/yy hh:mm)  \
# 0   2023-04-05  2023-06-05    current  ...                 6/21/05 10:54
# 1   2023-04-05  2023-06-05    current  ...                   9/6/05 9:13
#
#    Prob Fixed (mm/dd/yy hh:mm)  Down Time  Facilities             Hardware  \
# 0                6/21/05 11:00          6         NaN  Graphics Accel Hdwr
# 1                  9/6/05 9:19          6         NaN                  NaN
#
#   Human Error Network Undetermined        Software Same Event
# 0         NaN     NaN          NaN             NaN         No
# 1         NaN     NaN          NaN  Other Software         No
#
# [2 rows x 26 columns]

# %%
# rename column names
df = df.rename(columns={
    'machine type':'machine_type',
    'node install':'node_installed_date',
    'node prod':'node_in_production_date',
    'node decom':'node_decommissioned_date',
    'fru type':'fru_type',
    'num intercon':'num_interconnections',
    'Prob Started (mm/dd/yy hh:mm)':'problem_start_datetime',
    'Prob Fixed (mm/dd/yy hh:mm)':'problem_end_datetime',
    'Down Time':'down_time_mins',
    'Human Error':'human_error',
    'Same Event':'is_same_event'
})
df.head(2)
# Out:
#    System machine_type  nodes  procstot  procsinnode  nodenum  nodenumz  \
# 0       2      cluster   49.0    6152.0         80.0      0.0       0.0
# 1       2      cluster   49.0    6152.0         80.0      0.0       0.0
#
#   node_installed_date node_in_production_date node_decommissioned_date  ...  \
# 0          2023-04-05              2023-06-05                  current  ...
# 1          2023-04-05              2023-06-05                  current  ...
#
#   problem_start_datetime  problem_end_datetime  down_time_mins  Facilities  \
# 0          6/21/05 10:54         6/21/05 11:00               6         NaN
# 1            9/6/05 9:13           9/6/05 9:19               6         NaN
#
#               Hardware human_error Network Undetermined        Software  \
# 0  Graphics Accel Hdwr         NaN     NaN          NaN             NaN
# 1                  NaN         NaN     NaN          NaN  Other Software
#
#   is_same_event
# 0            No
# 1            No
#
# [2 rows x 26 columns]

# %%
df.isna().sum()
# Out:
# System                          0
# machine_type                  126
# nodes                         126
# procstot                      126
# procsinnode                   126
# nodenum                       126
# nodenumz                      126
# node_installed_date           126
# node_in_production_date       126
# node_decommissioned_date      126
# fru_type                      126
# mem                           126
# cputype                       126
# memtype                       126
# num_interconnections          126
# purpose                       126
# problem_start_datetime          0
# problem_end_datetime            0
# down_time_mins                  0
# Facilities                  23377
# Hardware                     9398
# human_error                 23590
# Network                     23318
# Undetermined                21087
# Software                    18378
# is_same_event                   0
# dtype: int64

# %%
# drop rows where machine_type isna
df = df[df['machine_type'].notna()]
df.isna().sum()
# Out:
# System                          0
# machine_type                    0
# nodes                           0
# procstot                        0
# procsinnode                     0
# nodenum                         0
# nodenumz                        0
# node_installed_date             0
# node_in_production_date         0
# node_decommissioned_date        0
# fru_type                        0
# mem                             0
# cputype                         0
# memtype                         0
# num_interconnections            0
# purpose                         0
# problem_start_datetime          0
# problem_end_datetime            0
# down_time_mins                  0
# Facilities                  23256
# Hardware                     9322
# human_error                 23464
# Network                     23193
# Undetermined                20972
# Software                    18311
# is_same_event                   0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23613 entries, 0 to 23738
# Data columns (total 26 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   System                    23613 non-null  int64
#  1   machine_type              23613 non-null  object
#  2   nodes                     23613 non-null  float64
#  3   procstot                  23613 non-null  float64
#  4   procsinnode               23613 non-null  float64
#  5   nodenum                   23613 non-null  float64
#  6   nodenumz                  23613 non-null  float64
#  7   node_installed_date       23613 non-null  object
#  8   node_in_production_date   23613 non-null  object
#  9   node_decommissioned_date  23613 non-null  object
#  10  fru_type                  23613 non-null  object
#  11  mem                       23613 non-null  float64
#  12  cputype                   23613 non-null  float64
#  13  memtype                   23613 non-null  float64
#  14  num_interconnections      23613 non-null  float64
#  15  purpose                   23613 non-null  object
#  16  problem_start_datetime    23613 non-null  object
#  17  problem_end_datetime      23613 non-null  object
#  18  down_time_mins            23613 non-null  int64
#  19  Facilities                357 non-null    object
#  20  Hardware                  14291 non-null  object
#  21  human_error               149 non-null    object
#  22  Network                   420 non-null    object
#  23  Undetermined              2641 non-null   object
#  24  Software                  5302 non-null   object
#  25  is_same_event             23613 non-null  object
# dtypes: float64(9), int64(2), object(15)
# memory usage: 4.9+ MB

# %%
df.node_installed_date.unique()
# Out:
# array(['2023-04-05', '1996-11-01', '2023-08-03', 'before tracking',
#        '2023-03-01', '2023-12-02', '2023-03-05', '2023-11-04',
#        '1996-10-01', '2023-03-02', '2023-08-02', '2023-10-01',
#        '2023-08-01', '1998-01-01', '1998-10-01', '2023-11-02'],
#       dtype=object)

# %%
# replace rows where node_installed_date == 'before tracking' with MIN date
df.loc[df["node_installed_date"] == "before tracking", "node_installed_date"] = '1996-10-01'
df.node_installed_date.unique()
# Out:
# array(['2023-04-05', '1996-11-01', '2023-08-03', '1996-10-01',
#        '2023-03-01', '2023-12-02', '2023-03-05', '2023-11-04',
#        '2023-03-02', '2023-08-02', '2023-10-01', '2023-08-01',
#        '1998-01-01', '1998-10-01', '2023-11-02'], dtype=object)

# %%
df.node_in_production_date.unique()
# Out:
# array(['2023-06-05', '1997-01-01', '2023-09-03', 'before tracking',
#        '2023-04-01', '2023-12-02', '2023-03-05', '2023-11-04',
#        '1996-12-01', '2023-05-02', '2023-10-02', '2023-12-01',
#        '2023-09-01', '1998-01-01', '1998-10-01', '2023-11-02'],
#       dtype=object)

# %%
# replace rows where node_in_production_date == 'before tracking' w/ MIN date
df.loc[df["node_in_production_date"] == "before tracking", "node_in_production_date"] = '1996-12-01'
df.node_in_production_date.unique()
# Out:
# array(['2023-06-05', '1997-01-01', '2023-09-03', '1996-12-01',
#        '2023-04-01', '2023-12-02', '2023-03-05', '2023-11-04',
#        '2023-05-02', '2023-10-02', '2023-12-01', '2023-09-01',
#        '1998-01-01', '1998-10-01', '2023-11-02'], dtype=object)

# %%
df.node_decommissioned_date.unique()
# Out:
# array(['current', '2023-11-05', '1999-12-01', '2023-06-05', '2023-09-02',
#        '2023-01-02', '2023-04-03', '2023-12-04', '2023-12-03'],
#       dtype=object)

# %%
# replace rows where node_decommissioned_date == 'before tracking' w/ MAX date
df.loc[df["node_decommissioned_date"] == "current", "node_decommissioned_date"] = '2023-12-04'
df.node_decommissioned_date.unique()
# Out:
# array(['2023-12-04', '2023-11-05', '1999-12-01', '2023-06-05',
#        '2023-09-02', '2023-01-02', '2023-04-03', '2023-12-03'],
#       dtype=object)

# %%
#  convert dates to datetime
df['problem_start_datetime'] = pd.to_datetime(df['problem_start_datetime'])
df['problem_end_datetime'] = pd.to_datetime(df['problem_end_datetime'])
df['node_installed_date'] = pd.to_datetime(df['node_installed_date'])
df['node_in_production_date'] = pd.to_datetime(df['node_in_production_date'])
df['node_decommissioned_date'] = pd.to_datetime(df['node_decommissioned_date'])
df.head(2)
# Out:
#    System machine_type  nodes  procstot  procsinnode  nodenum  nodenumz  \
# 0       2      cluster   49.0    6152.0         80.0      0.0       0.0
# 1       2      cluster   49.0    6152.0         80.0      0.0       0.0
#
#   node_installed_date node_in_production_date node_decommissioned_date  ...  \
# 0          2023-04-05              2023-06-05               2023-12-04  ...
# 1          2023-04-05              2023-06-05               2023-12-04  ...
#
#   problem_start_datetime  problem_end_datetime  down_time_mins  Facilities  \
# 0    2005-06-21 10:54:00   2005-06-21 11:00:00               6         NaN
# 1    2005-09-06 09:13:00   2005-09-06 09:19:00               6         NaN
#
#               Hardware human_error Network Undetermined        Software  \
# 0  Graphics Accel Hdwr         NaN     NaN          NaN             NaN
# 1                  NaN         NaN     NaN          NaN  Other Software
#
#   is_same_event
# 0            No
# 1            No
#
# [2 rows x 26 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23613 entries, 0 to 23738
# Data columns (total 26 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   System                    23613 non-null  int64
#  1   machine_type              23613 non-null  object
#  2   nodes                     23613 non-null  float64
#  3   procstot                  23613 non-null  float64
#  4   procsinnode               23613 non-null  float64
#  5   nodenum                   23613 non-null  float64
#  6   nodenumz                  23613 non-null  float64
#  7   node_installed_date       23613 non-null  datetime64[ns]
#  8   node_in_production_date   23613 non-null  datetime64[ns]
#  9   node_decommissioned_date  23613 non-null  datetime64[ns]
#  10  fru_type                  23613 non-null  object
#  11  mem                       23613 non-null  float64
#  12  cputype                   23613 non-null  float64
#  13  memtype                   23613 non-null  float64
#  14  num_interconnections      23613 non-null  float64
#  15  purpose                   23613 non-null  object
#  16  problem_start_datetime    23613 non-null  datetime64[ns]
#  17  problem_end_datetime      23613 non-null  datetime64[ns]
#  18  down_time_mins            23613 non-null  int64
#  19  Facilities                357 non-null    object
#  20  Hardware                  14291 non-null  object
#  21  human_error               149 non-null    object
#  22  Network                   420 non-null    object
#  23  Undetermined              2641 non-null   object
#  24  Software                  5302 non-null   object
#  25  is_same_event             23613 non-null  object
# dtypes: datetime64[ns](5), float64(9), int64(2), object(10)
# memory usage: 4.9+ MB

# %%
# convert float64 columns to int64
df2 = df.copy()
float_col = df2.select_dtypes(include=['float64'])
for col in float_col.columns.values:
    df2[col] = df2[col].astype('int64')
    
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23613 entries, 0 to 23738
# Data columns (total 26 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   System                    23613 non-null  int64
#  1   machine_type              23613 non-null  object
#  2   nodes                     23613 non-null  int64
#  3   procstot                  23613 non-null  int64
#  4   procsinnode               23613 non-null  int64
#  5   nodenum                   23613 non-null  int64
#  6   nodenumz                  23613 non-null  int64
#  7   node_installed_date       23613 non-null  datetime64[ns]
#  8   node_in_production_date   23613 non-null  datetime64[ns]
#  9   node_decommissioned_date  23613 non-null  datetime64[ns]
#  10  fru_type                  23613 non-null  object
#  11  mem                       23613 non-null  int64
#  12  cputype                   23613 non-null  int64
#  13  memtype                   23613 non-null  int64
#  14  num_interconnections      23613 non-null  int64
#  15  purpose                   23613 non-null  object
#  16  problem_start_datetime    23613 non-null  datetime64[ns]
#  17  problem_end_datetime      23613 non-null  datetime64[ns]
#  18  down_time_mins            23613 non-null  int64
#  19  Facilities                357 non-null    object
#  20  Hardware                  14291 non-null  object
#  21  human_error               149 non-null    object
#  22  Network                   420 non-null    object
#  23  Undetermined              2641 non-null   object
#  24  Software                  5302 non-null   object
#  25  is_same_event             23613 non-null  object
# dtypes: datetime64[ns](5), int64(11), object(10)
# memory usage: 4.9+ MB

# %%
df2.head()
# Out:
#    System machine_type  nodes  procstot  procsinnode  nodenum  nodenumz  \
# 0       2      cluster     49      6152           80        0         0
# 1       2      cluster     49      6152           80        0         0
# 2       2      cluster     49      6152           80        0         0
# 3       2      cluster     49      6152           80        0         0
# 4       2      cluster     49      6152           80        0         0
#
#   node_installed_date node_in_production_date node_decommissioned_date  ...  \
# 0          2023-04-05              2023-06-05               2023-12-04  ...
# 1          2023-04-05              2023-06-05               2023-12-04  ...
# 2          2023-04-05              2023-06-05               2023-12-04  ...
# 3          2023-04-05              2023-06-05               2023-12-04  ...
# 4          2023-04-05              2023-06-05               2023-12-04  ...
#
#   problem_start_datetime  problem_end_datetime  down_time_mins  Facilities  \
# 0    2005-06-21 10:54:00   2005-06-21 11:00:00               6         NaN
# 1    2005-09-06 09:13:00   2005-09-06 09:19:00               6         NaN
# 2    2005-09-06 10:32:00   2005-09-06 10:46:00              14         NaN
# 3    2005-09-06 14:50:00   2005-09-06 15:08:00              18         NaN
# 4    2005-09-08 16:52:00   2005-09-08 16:57:00               5         NaN
#
#               Hardware human_error Network  Undetermined        Software  \
# 0  Graphics Accel Hdwr         NaN     NaN           NaN             NaN
# 1                  NaN         NaN     NaN           NaN  Other Software
# 2                  NaN         NaN     NaN  Undetermined             NaN
# 3                  NaN         NaN     NaN           NaN  Other Software
# 4                  NaN         NaN     NaN  Undetermined             NaN
#
#   is_same_event
# 0            No
# 1            No
# 2            No
# 3            No
# 4            No
#
# [5 rows x 26 columns]

# %%
df3 = df2.copy()
float_col = df3.select_dtypes(include=['object'])
for col in float_col.columns.values:
    df3[col] = df3[col].astype('string')
    
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23613 entries, 0 to 23738
# Data columns (total 26 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   System                    23613 non-null  int64
#  1   machine_type              23613 non-null  string
#  2   nodes                     23613 non-null  int64
#  3   procstot                  23613 non-null  int64
#  4   procsinnode               23613 non-null  int64
#  5   nodenum                   23613 non-null  int64
#  6   nodenumz                  23613 non-null  int64
#  7   node_installed_date       23613 non-null  datetime64[ns]
#  8   node_in_production_date   23613 non-null  datetime64[ns]
#  9   node_decommissioned_date  23613 non-null  datetime64[ns]
#  10  fru_type                  23613 non-null  string
#  11  mem                       23613 non-null  int64
#  12  cputype                   23613 non-null  int64
#  13  memtype                   23613 non-null  int64
#  14  num_interconnections      23613 non-null  int64
#  15  purpose                   23613 non-null  string
#  16  problem_start_datetime    23613 non-null  datetime64[ns]
#  17  problem_end_datetime      23613 non-null  datetime64[ns]
#  18  down_time_mins            23613 non-null  int64
#  19  Facilities                357 non-null    string
#  20  Hardware                  14291 non-null  string
#  21  human_error               149 non-null    string
#  22  Network                   420 non-null    string
#  23  Undetermined              2641 non-null   string
#  24  Software                  5302 non-null   string
#  25  is_same_event             23613 non-null  string
# dtypes: datetime64[ns](5), int64(11), string(10)
# memory usage: 4.9 MB

# %%
df3.head()
# Out:
#    System machine_type  nodes  procstot  procsinnode  nodenum  nodenumz  \
# 0       2      cluster     49      6152           80        0         0
# 1       2      cluster     49      6152           80        0         0
# 2       2      cluster     49      6152           80        0         0
# 3       2      cluster     49      6152           80        0         0
# 4       2      cluster     49      6152           80        0         0
#
#   node_installed_date node_in_production_date node_decommissioned_date  ...  \
# 0          2023-04-05              2023-06-05               2023-12-04  ...
# 1          2023-04-05              2023-06-05               2023-12-04  ...
# 2          2023-04-05              2023-06-05               2023-12-04  ...
# 3          2023-04-05              2023-06-05               2023-12-04  ...
# 4          2023-04-05              2023-06-05               2023-12-04  ...
#
#   problem_start_datetime  problem_end_datetime  down_time_mins  Facilities  \
# 0    2005-06-21 10:54:00   2005-06-21 11:00:00               6        <NA>
# 1    2005-09-06 09:13:00   2005-09-06 09:19:00               6        <NA>
# 2    2005-09-06 10:32:00   2005-09-06 10:46:00              14        <NA>
# 3    2005-09-06 14:50:00   2005-09-06 15:08:00              18        <NA>
# 4    2005-09-08 16:52:00   2005-09-08 16:57:00               5        <NA>
#
#               Hardware human_error Network  Undetermined        Software  \
# 0  Graphics Accel Hdwr        <NA>    <NA>          <NA>            <NA>
# 1                 <NA>        <NA>    <NA>          <NA>  Other Software
# 2                 <NA>        <NA>    <NA>  Undetermined            <NA>
# 3                 <NA>        <NA>    <NA>          <NA>  Other Software
# 4                 <NA>        <NA>    <NA>  Undetermined            <NA>
#
#   is_same_event
# 0            No
# 1            No
# 2            No
# 3            No
# 4            No
#
# [5 rows x 26 columns]

# %%
df.to_csv('data/0_all_systems.csv', sep=',', encoding='utf-8')
